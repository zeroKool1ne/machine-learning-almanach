# %% [markdown]
# # Übungen: Hyperparameter Tuning
#
# Wir arbeiten mit dem **California Housing** Datensatz (Regression).

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Aufgabe 1: Daten laden & vorbereiten
#
# Lade den California Housing Datensatz, erstelle X und y, und mache einen Train/Test Split (80/20).

# %%
# TODO: Datensatz laden
housing = fetch_california_housing()

# TODO: X und y erstellen
X = ___
y = ___

# TODO: Train/Test Split
X_train, X_test, y_train, y_test = ___

print(f"Training: {X_train.shape} | Test: {X_test.shape}")

# %% [markdown]
# ## Aufgabe 2: Baseline Modell
#
# Trainiere einen Random Forest **ohne** Hyperparameter und speichere den R² Score als Baseline.

# %%
# TODO: Baseline Random Forest trainieren
rf = ___
rf.fit(___)

baseline_r2 = rf.score(X_test, y_test)
print(f"Baseline R²: {baseline_r2:.4f}")

# %% [markdown]
# ## Aufgabe 3: Grid Search
#
# Definiere ein Grid mit folgenden Parametern und führe GridSearchCV durch:
# - `n_estimators`: [50, 100, 200]
# - `max_depth`: [5, 10, 20]
# - `min_samples_split`: [2, 5]
#
# Wie viele Kombinationen gibt es? (rechne kurz nach!)

# %%
# TODO: Grid definieren
grid = ___

# TODO: GridSearchCV erstellen (cv=3)
grid_search = GridSearchCV(___)

# TODO: Trainieren
grid_search.fit(___)

print("Beste Parameter:", grid_search.best_params_)
print(f"Bester CV-Score (R²): {grid_search.best_score_:.4f}")
print(f"Test R²: {grid_search.score(X_test, y_test):.4f}")

# %% [markdown]
# ## Aufgabe 4: Random Search
#
# Erstelle einen großen Parameterraum für GradientBoostingRegressor und führe RandomizedSearchCV mit `n_iter=10` durch.

# %%
# TODO: Großen Parameterraum definieren
random_grid = {
    'n_estimators': [int(x) for x in np.linspace(100, 1000, 10)],
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'min_samples_split': [2, 5, 10],
    'subsample': [0.8, 0.9, 1.0]
}

# TODO: RandomizedSearchCV (n_iter=10, cv=3)
random_search = RandomizedSearchCV(___)
random_search.fit(___)

print("Beste Parameter:", random_search.best_params_)
print(f"Test R²: {random_search.score(X_test, y_test):.4f}")

# %% [markdown]
# ## Aufgabe 5: Vergleich & Fazit
#
# Vergleiche alle 3 Modelle (Baseline, Grid Search, Random Search) in einer Tabelle.

# %%
# TODO: Vergleichstabelle erstellen
results = pd.DataFrame({
    'Modell': ['Baseline', 'Grid Search', 'Random Search'],
    'R²': [
        baseline_r2,
        grid_search.score(X_test, y_test),
        random_search.score(X_test, y_test)
    ]
})

print(results)

# Frage: Welches Modell ist am besten? Hat Tuning geholfen?

# %% [markdown]
# ## Bonusaufgabe: Bestes Modell analysieren
#
# Hol dir das beste Modell aus dem Grid Search und zeige die Feature Importances als Balkendiagramm.

# %%
import matplotlib.pyplot as plt

# TODO: Bestes Modell aus grid_search holen
best_model = ___

# TODO: Feature Importances plotten
importances = pd.Series(best_model.feature_importances_, index=housing.feature_names)
importances.sort_values(ascending=False).plot(kind='bar', figsize=(10, 5))
plt.title('Feature Importance — Bestes Grid Search Modell')
plt.tight_layout()
plt.show()

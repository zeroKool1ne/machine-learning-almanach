# %% [markdown]
# # Übungen: Unausgeglichene Daten
#
# Wir verwenden den **Titanic-Datensatz** — überlebt/nicht überlebt.

# %% [markdown]
# ## Aufgabe 1: Klassenverteilung analysieren

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

titanic = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/titanic_train.csv")

# TODO: Klassenverteilung von 'Survived' ausgeben (absolut + prozentual)
# TODO: Balkendiagramm der Verteilung
# Frage: Ist das ein ausgewogener Datensatz?

# %% [markdown]
# ## Aufgabe 2: Daten vorbereiten

# %%
# TODO: Cabin-Spalte droppen
# TODO: Zeilen mit fehlenden Age-Werten droppen
# TODO: Sex als 0/1 enkodieren (male=0, female=1)
# TODO: Nur numerische Features behalten: Pclass, Sex, Age, SibSp, Parch, Fare
# TODO: Train/Test Split (80/20, random_state=42)

# %% [markdown]
# ## Aufgabe 3: Baseline Modell

# %%
# TODO: Logistische Regression ohne Ausbalancierung trainieren
# TODO: Precision, Recall, F1 für Klasse 1 (überlebt) ausgeben
# TODO: Confusion Matrix anzeigen
# Frage: Wie gut erkennt das Modell die Überlebenden?

# %% [markdown]
# ## Aufgabe 4: Oversampling anwenden

# %%
from sklearn.utils import resample

# TODO: Trainingsdaten mit Oversampling ausbalancieren
# TODO: Neues Modell trainieren
# TODO: Precision, Recall, F1 vergleichen mit Baseline
# Achtung: Testdaten NICHT ausbalancieren!

# %% [markdown]
# ## Aufgabe 5: SMOTE anwenden

# %%
try:
    from imblearn.over_sampling import SMOTE
    # TODO: SMOTE auf Trainingsdaten anwenden
    # TODO: Modell trainieren und Metriken vergleichen
    pass
except ImportError:
    print("pip install imbalanced-learn")

# %% [markdown]
# ## Aufgabe 6: Alle Methoden vergleichen

# %%
# TODO: Erstelle eine Tabelle mit allen 3 Methoden:
# Baseline | Oversampling | SMOTE
# Precision, Recall, F1

# Welche Methode funktioniert am besten?
# Was ist der Trade-off zwischen Precision und Recall?

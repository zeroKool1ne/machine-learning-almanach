# %% [markdown]
# # Übungen: Feature Engineering
#
# Wir arbeiten mit einem simulierten HR-Datensatz.

# %% [markdown]
# ## Aufgabe 1: Kategorische Variablen kodieren

# %%
import pandas as pd
import numpy as np

# Datensatz erstellen
hr = pd.DataFrame({
    'Abteilung': ['IT', 'Marketing', 'IT', 'HR', 'Marketing', 'HR'],
    'Erfahrung': ['Junior', 'Senior', 'Senior', 'Junior', 'Junior', 'Senior'],
    'Alter': [28, 45, 35, 29, 31, 50],
    'Gehalt': [55000, 90000, 75000, 48000, 52000, 85000]
})

# TODO: One-Hot Encoding für 'Abteilung'
# TODO: Label Encoding für 'Erfahrung' (Junior=0, Senior=1)
# TODO: Alles in einen DataFrame kombinieren (nur numerische Spalten)

# %% [markdown]
# ## Aufgabe 2: Normalisierung verstehen

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

hr = pd.DataFrame({
    'Alter': [28, 45, 35, 29, 31, 50, 38, 42, 27, 55],
    'Erfahrung_jahre': [3, 20, 10, 4, 6, 28, 12, 15, 2, 30],
    'Wochenstunden': [40, 45, 42, 38, 40, 45, 43, 41, 38, 46],
    'Gehalt': [55000, 90000, 72000, 48000, 58000, 95000, 70000, 75000, 45000, 98000]
})

X = hr.drop('Gehalt', axis=1)
y = hr['Gehalt']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# TODO: KNN ohne Normalisierung trainieren, RMSE berechnen
# TODO: KNN mit MinMaxScaler trainieren, RMSE berechnen
# TODO: KNN mit StandardScaler trainieren, RMSE berechnen
# TODO: Vergleiche und erkläre den Unterschied

# %% [markdown]
# ## Aufgabe 3: Korrelationsanalyse

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml

dataset = fetch_openml(name='boston', version=1)
X_b = dataset.data.astype(float)
y_b = dataset.target.astype(float)

# TODO: Berechne die Korrelationsmatrix für X_b
# TODO: Visualisiere als Heatmap
# TODO: Welche 3 Features korrelieren am stärksten mit dem Hauspreis?
# TODO: Gibt es Features die sehr stark miteinander korrelieren (>0.85)?

# %% [markdown]
# ## Aufgabe 4 (Bonus): Polynamiale Features

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

# TODO: Vergleiche Lineare Regression mit
#       Grad-2 Polynomialfeatures und
#       Grad-3 Polynomialfeatures
# Verwende 5-Fold CV (scoring='r2')
# Hinweis: Bei hohem Grad -> Overfitting!

# %% [markdown]
# # Übungen: Dimensionsreduktion mit PCA
#
# Beantworte zuerst die Fragen, dann schreibe den Code!

# %% [markdown]
# ## Frage 1
# Was bedeutet 'Explained Variance Ratio'? Wenn `pca.explained_variance_ratio_ = [0.45, 0.25]`, was heißt das?

# %%
# Deine Antwort als Kommentar:
#

# %% [markdown]
# ## Aufgabe 1 — Iris Dataset PCA
#
# Lade das Iris Dataset, skaliere es und reduziere auf 2 Komponenten.
# Visualisiere das Ergebnis als Scatter Plot mit Farben nach Species.
# Wie viel Varianz erklären die 2 Komponenten zusammen?

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Dein Code hier:

# %% [markdown]
# ## Aufgabe 2 — Optimale Komponentenanzahl
#
# Erstelle einen Scree Plot für das Wine Dataset.
# Wie viele Komponenten brauchst du für mindestens 90% Varianz?

# %%
from sklearn.datasets import load_wine
import numpy as np

# Dein Code hier:

# %% [markdown]
# ## Aufgabe 3 — PCA Pipeline
#
# Baue eine Pipeline: StandardScaler → PCA(80%) → RandomForestClassifier
# Teste auf dem Wine Dataset. Vergleiche mit/ohne PCA.
# Wie viele Features werden nach PCA genutzt?

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Dein Code hier:

# %% [markdown]
# ## Aufgabe 4 — K-Means + PCA Visualisierung
#
# Wende K-Means (K=3) auf dem Wine Dataset an.
# Nutze PCA(2) um das Ergebnis zu visualisieren.
# Vergleiche im gleichen Plot: links Cluster-Labels, rechts echte Labels.

# %%
from sklearn.cluster import KMeans

# Dein Code hier:

# %% [markdown]
# ## Bonus — Frage zum Nachdenken
#
# Du hast ein Dataset mit 50 Features. PCA(0.95) ergibt 8 Komponenten.
# Dein Modell mit 8 PCA-Features hat 92% Accuracy, mit allen 50 Features 93%.
#
# Würdest du PCA trotzdem verwenden? Warum/warum nicht?

# %%
# Deine Antwort:
#

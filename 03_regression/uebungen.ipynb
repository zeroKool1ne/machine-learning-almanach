# %% [markdown]
# # Übungen: Regression
#
# Wir verwenden den **Diabetes-Datensatz** von Sklearn.
# Ziel: Vorhersage des Krankheitsfortschritts (eine Zahl).

# %% [markdown]
# ## Aufgabe 1: Lineare Regression Grundlagen

# %%
from sklearn.datasets import load_diabetes
import numpy as np

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target
print(f"Features: {diabetes.feature_names}")
print(f"Ziel: Krankheitsfortschritt, Bereich {y.min():.0f}-{y.max():.0f}")

# TODO: Train/Test-Split (75/25, random_state=42)
# TODO: Lineare Regression trainieren
# TODO: RMSE und R² berechnen und ausgeben

# %%
# Musterlösung:
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
lin = LinearRegression().fit(X_train, y_train)
y_pred = lin.predict(X_test)
print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred)):.2f}")
print(f"R²:   {r2_score(y_test, y_pred):.4f}")

# %% [markdown]
# ## Aufgabe 2: Ridge vs. Lasso

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.preprocessing import StandardScaler

# WICHTIG: Bei Ridge/Lasso immer StandardScaler verwenden!

# TODO: Skaliere die Daten (fit NUR auf Training!)
# TODO: Trainiere Ridge mit alpha=1 und alpha=100
# TODO: Trainiere Lasso mit alpha=0.1 und alpha=10
# TODO: Vergleiche R² Scores
# TODO: Bei welchem Lasso-Alpha werden Features auf 0 gesetzt?

# %% [markdown]
# ## Aufgabe 3: Bestes Alpha mit Cross-Validation finden

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Lade Diabetes-Datensatz
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
X, y = diabetes.data, diabetes.target

scaler = StandardScaler()
X_s = scaler.fit_transform(X)

alphas = [0.001, 0.01, 0.1, 1, 10, 100, 1000]

# TODO: For-Schleife: für jedes alpha, berechne 5-Fold CV R²-Score
# TODO: Visualisiere als Liniendiagramm (x=alpha log-Skala, y=CV Score)
# TODO: Bestes Alpha ausgeben

# %% [markdown]
# ## Aufgabe 4: Vorhersagen visualisieren

# %%
import matplotlib.pyplot as plt
# Trainiere die Lineare Regression
# Erstelle einen Scatter-Plot: echte Werte (x-Achse) vs. Vorhersagen (y-Achse)
# Zeichne die Diagonale (perfekte Vorhersage) in rot

# Interpretation: Was bedeutet ein Punkt weit unter der Diagonale?

# %% [markdown]
# ## Aufgabe 5 (Bonus): Koeffizienten interpretieren

# %%
import pandas as pd
# Trainiere Lineare Regression auf dem Diabetes-Datensatz
# Erstelle ein Balkendiagramm der Koeffizienten
# Welche Features treiben den Krankheitsfortschritt am stärksten?
# Welche senken ihn?
